# %%
import io
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from pylab import rcParams
from itertools import product
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# ## Carregamento dos dados da Soja

# %%
dct = {}
dct['codigo'] = 'soja'

# %%
df = pd.read_pickle(f'../dados/cepea-{dct["codigo"]}.p')

# %%
# Converte index para data
df.index = pd.to_datetime(df.index, format='%d/%m/%Y')

# Slice para somente o período desejado
df = df['01/01/2007':'01/01/2021']

# %%
# Como uma possível sazonalidade nos preços deve ter ciclo anual, com variação mensal, 
# faremos o resample da série para a média de cada mês (colocamos no início do mês por convenção, mas ideal seria fim do mês)
df_mes = df.resample('MS').mean()
df.isnull().any()
# Out:
# preco_real     False
# preco_dolar    False
# dtype: bool

# %% [markdown]
# #### Rendimento (produtividade por área) da soja

# %%
rendimento = pd.read_pickle('../dados/rendimento_soja.p')
rendimento.columns =['prd_dd']

df_join = df_mes.join(rendimento,how="inner")
df_join = df_join.asfreq('MS')

df_join.corr()
# Out:
#              preco_real  preco_dolar    prd_dd
# preco_real     1.000000     0.077259  0.558455
# preco_dolar    0.077259     1.000000 -0.349639
# prd_dd         0.558455    -0.349639  1.000000

# %%
df_join
# Out:
#             preco_real  preco_dolar  prd_dd
# data
# 2007-01-01   33.676364    15.747273    2726
# 2007-02-01   34.709444    16.549444    2739
# 2007-03-01   34.005909    16.287273    2752
# 2007-04-01   31.956000    15.724000    2781
# 2007-05-01   32.123636    16.228636    2850
# ...                ...          ...     ...
# 2020-08-01  128.591905    23.546667    3265
# 2020-09-01  141.199048    26.131905    3275
# 2020-10-01  159.635238    28.357619    3279
# 2020-11-01  164.992500    30.437500    3280
# 2020-12-01  152.562500    29.680500    3280
#
# [168 rows x 3 columns]

# %%
df_join.drop('preco_real', axis=1, inplace=True)

# %%
def plot_2axis(ds, title=None, lag=None): # Recebe dataframe com 2 colunas
    fig0, ax0 = plt.subplots()
    ax1 = ax0.twinx()

    if title: plt.title(title)
    ds.iloc[:,0].plot(kind='line', ax=ax0, figsize=(12,5))
    
    shft = ds.iloc[:,0].shift()
    shft.iloc[0] = ds.iloc[0,0]
    if lag == True: shft.plot(kind='line', ax=ax0, style='-')

    ds.iloc[:,1].plot(kind='line', secondary_y=True, ax=ax1, color='r')
    plt.show()
    plt.close()
    
plot_2axis(df_join, "Preço vs. Produtividade (vermelho)")

# %%
# Converte para séries estacionárias (primeira diferença)
data = np.log(df_join).diff().dropna()
print(df_join.shape)
print(data.shape)
# data possui um item a menos que df_join, pois perde o primeiro com a derivada.
# Out:
# (168, 2)
# (167, 2)

# %%
# Plota série tornada estacionária
plt.figure(figsize=(12,5))
plt.plot(data)
plt.show()

# %%
# Separa Train Test (12 meses = ano 2020)
test_size = 12
train = data[:-test_size]
test = data[-test_size:]

# %%
import statsmodels.api as sm
from statsmodels.tsa.api import VAR
from statsmodels.tsa.base.datetools import dates_from_str

# Fit somente no set de treino
maxlags = 10

model = VAR(train)
results = model.fit(maxlags=maxlags, ic='aic')
results.summary()
# Out:
#   Summary of Regression Results
# ==================================
# Model:                         VAR
# Method:                        OLS
# Date:           Fri, 29, Jan, 2021
# Time:                     18:29:19
# --------------------------------------------------------------------
# No. of Equations:         2.00000    BIC:                   -13.4680
# Nobs:                     154.000    HQIC:                  -13.5382
# Log likelihood:           615.111    FPE:                1.25763e-06
# AIC:                     -13.5863    Det(Omega_mle):     1.21003e-06
# --------------------------------------------------------------------
# Results for equation preco_dolar
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                  0.001427         0.004203            0.340           0.734
# L1.preco_dolar         0.321088         0.076194            4.214           0.000
# L1.prd_dd             -0.419639         0.199354           -2.105           0.035
# =================================================================================
#
# Results for equation prd_dd
# =================================================================================
#                     coefficient       std. error           t-stat            prob
# ---------------------------------------------------------------------------------
# const                  0.000835         0.001735            0.481           0.631
# L1.preco_dolar         0.007159         0.031457            0.228           0.820
# L1.prd_dd              0.103209         0.082304            1.254           0.210
# =================================================================================
#
# Correlation matrix of residuals
#                preco_dolar    prd_dd
# preco_dolar       1.000000 -0.180862
# prd_dd           -0.180862  1.000000

# %%
irf = results.irf(10)
irf.plot()
plt.show()

# %%
# Ordem do modelo, escolhida pelo critério AIC
lag_order = results.k_ar
print("lag_order ",lag_order)
# Out:
# lag_order  1

# %%
def gera_inputs(tr, tt, lags):
    ret = []
    size = tt.shape[0]
    full = tr.append(tt)
    for e in range(size):
        ret.append(full[-size+e-lags:-size+e if -size+e < 0 else None])
    return ret

forecasts_input = gera_inputs(train, test, lag_order)
# forecasts_input

# %%
# Gera Predições
price_forecasts = []

for e in forecasts_input:
    price_forecasts.append(results.forecast(e.values, 1)[0][0])
    
# price_forecasts # para o ano 2020

# %%
def revert(last_absolute_value, transformada): 
    # Recebe: Escalar do último ponto absoluto anterior às diferenciadas E pandas series ou numpy com valores transformados
    s = transformada if type(transformada) == np.ndarray else transformada.to_numpy()
    first = np.log(last_absolute_value)
    a_retornar = np.insert(s, 0, first, axis=0)
    return pd.Series(np.exp(a_retornar.cumsum())[1:])

# %%
# Transformação reversa
# Pega o último valor antes do set de test (-test_size-1)
invert_forecasts = revert(df_join.preco_dolar[-test_size-1:-test_size], np.array(price_forecasts))

# Tudo ok, porque todas as previsões são in sample
invert_forecasts.index = test.index

plt.plot(invert_forecasts, color='r')
plt.plot(df_join.preco_dolar[-test_size:], color='b')

# %%
# Teste diferenças
# d_fore['prod'] = 1 toda vez que a previsão acertou a direção da variação do preço para o próximo mês
#                  0 quando errou a direção do preço

d_fore = pd.DataFrame(dtype="float")
d_fore['forecasts'] = np.array(invert_forecasts.values)
d_fore['real'] = df_join.preco_dolar[-test_size:].values
d_fore = d_fore.apply(np.gradient)
d_fore['prod'] = d_fore.apply(np.prod, axis=1)
d_fore['prod'] = d_fore['prod'].apply(lambda x: 1 if x > 0 else 0)

print(f'Acurácia da direção da previsão: ', d_fore["prod"].value_counts()[1]/d_fore.shape[0])
# Out:
# Acurácia da direção da previsão:  0.9166666666666666

# %%
# previsão do modelo para todo o período de teste
# geração de inputs
ret = []
size = data.shape[0]
for e in range(size):
    ee = e + 1
    ret.append(data[-size+ee-lag_order:-size+ee if -size+ee < 0 else None])

# %%
def correct_size(x):
    if len(x) == lag_order: return True
ret1 = list(filter(correct_size, ret))
ret1
# Out:
# [            preco_dolar    prd_dd
#  data
#  2007-02-01     0.049685  0.004758,
#              preco_dolar    prd_dd
#  data
#  2007-03-01    -0.015969  0.004735,
#              preco_dolar    prd_dd
#  data
#  2007-04-01    -0.035196  0.010483,
#              preco_dolar    prd_dd
#  data
#  2007-05-01     0.031589  0.024508,
#              preco_dolar    prd_dd
#  data
#  2007-06-01      0.04908 -0.003515,
#              preco_dolar    prd_dd
#  data
#  2007-07-01      0.04747 -0.004588,
#              preco_dolar  prd_dd
#  data
#  2007-08-01     0.055536     0.0,
#              preco_dolar    prd_dd
#  data
#  2007-09-01     0.141791 -0.001062,
#              preco_dolar  prd_dd
#  data
#  2007-10-01     0.073984     0.0,
#              preco_dolar    prd_dd
#  data
#  2007-11-01      0.03417 -0.001417,
#              preco_dolar    prd_dd
#  data
#  2007-12-01     0.016194 -0.000355,
#              preco_dolar    prd_dd
#  data
#  2008-01-01     0.091575 -0.011058,
#              preco_dolar    prd_dd
#  data
#  2008-02-01     0.069284  0.016717,
#              preco_dolar   prd_dd
#  data
#  2008-03-01    -0.028136  0.00141,
#              preco_dolar    prd_dd
#  data
#  2008-04-01    -0.016258 -0.012048,
#              preco_dolar    prd_dd
#  data
#  2008-05-01     0.014979  0.005688,
#              preco_dolar    prd_dd
#  data
#  2008-06-01     0.140433 -0.000709,
#              preco_dolar  prd_dd
#  data
#  2008-07-01     0.027999     0.0,
#              preco_dolar   prd_dd
#  data
#  2008-08-01    -0.136237 -0.00142,
#              preco_dolar   prd_dd
#  data
#  2008-09-01     -0.08029  0.00071,
#              preco_dolar    prd_dd
#  data
#  2008-10-01    -0.223377 -0.000355,
#              preco_dolar    prd_dd
#  data
#  2008-11-01    -0.028508  0.000355,
#              preco_dolar  prd_dd
#  data
#  2008-12-01     -0.06736     0.0,
#              preco_dolar    prd_dd
#  data
#  2009-01-01     0.125739 -0.046875,
#              preco_dolar    prd_dd
#  data
#  2009-02-01    -0.035955 -0.004474,
#              preco_dolar    prd_dd
#  data
#  2009-03-01     -0.03254  0.012625,
#              preco_dolar    prd_dd
#  data
#  2009-04-01     0.098391 -0.018247,
#              preco_dolar    prd_dd
#  data
#  2009-05-01     0.118398 -0.009819,
#              preco_dolar    prd_dd
#  data
#  2009-06-01     0.042612 -0.006473,
#              preco_dolar  prd_dd
#  data
#  2009-07-01    -0.033238     0.0,
#              preco_dolar  prd_dd
#  data
#  2009-08-01     0.047654     0.0,
#              preco_dolar    prd_dd
#  data
#  2009-09-01     -0.06433  0.000382,
#              preco_dolar    prd_dd
#  data
#  2009-10-01    -0.004674  0.001907,
#              preco_dolar  prd_dd
#  data
#  2009-11-01    -0.040089     0.0,
#              preco_dolar  prd_dd
#  data
#  2009-12-01    -0.028175     0.0,
#              preco_dolar    prd_dd
#  data
#  2010-01-01    -0.045523  0.089961,
#              preco_dolar    prd_dd
#  data
#  2010-02-01     -0.08349  0.012805,
#              preco_dolar    prd_dd
#  data
#  2010-03-01     0.007258  0.001031,
#              preco_dolar    prd_dd
#  data
#  2010-04-01     0.017659  0.006847,
#              preco_dolar    prd_dd
#  data
#  2010-05-01    -0.007386 -0.003075,
#              preco_dolar    prd_dd
#  data
#  2010-06-01     0.017037 -0.002398,
#              preco_dolar    prd_dd
#  data
#  2010-07-01     0.083021  0.004108,
#              preco_dolar    prd_dd
#  data
#  2010-08-01     0.063778  0.002729,
#              preco_dolar  prd_dd
#  data
#  2010-09-01     0.044182     0.0,
#              preco_dolar    prd_dd
#  data
#  2010-10-01     0.041705  0.000681,
#              preco_dolar  prd_dd
#  data
#  2010-11-01     0.055533     0.0,
#              preco_dolar    prd_dd
#  data
#  2010-12-01     0.019551  0.000681,
#              preco_dolar    prd_dd
#  data
#  2011-01-01     0.034895 -0.027947,
#              preco_dolar    prd_dd
#  data
#  2011-02-01     0.016496  0.017687,
#              preco_dolar    prd_dd
#  data
#  2011-03-01    -0.031156  0.034463,
#              preco_dolar    prd_dd
#  data
#  2011-04-01    -0.003326  0.009914,
#              preco_dolar    prd_dd
#  data
#  2011-05-01    -0.003468  0.018247,
#              preco_dolar    prd_dd
#  data
#  2011-06-01     0.016745  0.004189,
#              preco_dolar    prd_dd
#  data
#  2011-07-01      0.02841  0.000321,
#              preco_dolar  prd_dd
#  data
#  2011-08-01    -0.002303     0.0,
#              preco_dolar    prd_dd
#  data
#  2011-09-01    -0.041976 -0.000321,
#              preco_dolar    prd_dd
#  data
#  2011-10-01    -0.079812  0.000643,
#              preco_dolar  prd_dd
#  data
#  2011-11-01    -0.027111     0.0,
#              preco_dolar    prd_dd
#  data
#  2011-12-01    -0.027736 -0.000321,
#              preco_dolar    prd_dd
#  data
#  2012-01-01     0.066079 -0.090788,
#              preco_dolar    prd_dd
#  data
#  2012-02-01     0.035765 -0.028201,
#              preco_dolar    prd_dd
#  data
#  2012-03-01      0.06359 -0.025671,
#              preco_dolar    prd_dd
#  data
#  2012-04-01     0.060097 -0.005588,
#              preco_dolar    prd_dd
#  data
#  2012-05-01    -0.011435 -0.012782,
#              preco_dolar    prd_dd
#  data
#  2012-06-01     0.032049 -0.001136,
#              preco_dolar  prd_dd
#  data
#  2012-07-01     0.164111     0.0,
#              preco_dolar    prd_dd
#  data
#  2012-08-01     0.076235  0.001514,
#              preco_dolar   prd_dd
#  data
#  2012-09-01     0.014821 -0.00607,
#              preco_dolar    prd_dd
#  data
#  2012-10-01    -0.137831  0.001521,
#              preco_dolar   prd_dd
#  data
#  2012-11-01    -0.019885  0.00038,
#              preco_dolar    prd_dd
#  data
#  2012-12-01    -0.004524  0.000759,
#              preco_dolar    prd_dd
#  data
#  2013-01-01    -0.026468  0.140009,
#              preco_dolar    prd_dd
#  data
#  2013-02-01    -0.089467  0.000989,
#              preco_dolar    prd_dd
#  data
#  2013-03-01    -0.040105 -0.032153,
#              preco_dolar   prd_dd
#  data
#  2013-04-01    -0.048315 -0.00034,
#              preco_dolar    prd_dd
#  data
#  2013-05-01     0.022138 -0.001363,
#              preco_dolar    prd_dd
#  data
#  2013-06-01     0.040645  0.000682,
#              preco_dolar    prd_dd
#  data
#  2013-07-01    -0.026556 -0.000682,
#              preco_dolar  prd_dd
#  data
#  2013-08-01    -0.033077     0.0,
#              preco_dolar    prd_dd
#  data
#  2013-09-01     0.085045  0.000341,
#              preco_dolar  prd_dd
#  data
#  2013-10-01     0.038604     0.0,
#              preco_dolar  prd_dd
#  data
#  2013-11-01    -0.014529     0.0,
#              preco_dolar    prd_dd
#  data
#  2013-12-01    -0.009281 -0.000682,
#              preco_dolar    prd_dd
#  data
#  2014-01-01    -0.080968  0.049245,
#              preco_dolar    prd_dd
#  data
#  2014-02-01     -0.03549 -0.031665,
#              preco_dolar    prd_dd
#  data
#  2014-03-01     0.058896 -0.029589,
#              preco_dolar    prd_dd
#  data
#  2014-04-01     0.024921  0.000345,
#              preco_dolar    prd_dd
#  data
#  2014-05-01    -0.000205 -0.009709,
#              preco_dolar    prd_dd
#  data
#  2014-06-01    -0.004595 -0.003141,
#              preco_dolar    prd_dd
#  data
#  2014-07-01    -0.046518  0.001048,
#              preco_dolar  prd_dd
#  data
#  2014-08-01    -0.022318     0.0,
#              preco_dolar    prd_dd
#  data
#  2014-09-01    -0.089856 -0.002097,
#              preco_dolar  prd_dd
#  data
#  2014-10-01    -0.079446     0.0,
#              preco_dolar  prd_dd
#  data
#  2014-11-01    -0.041182     0.0,
#              preco_dolar  prd_dd
#  data
#  2014-12-01    -0.034268     0.0,
#              preco_dolar    prd_dd
#  data
#  2015-01-01      0.00176  0.065347,
#              preco_dolar    prd_dd
#  data
#  2015-02-01     -0.02558 -0.009882,
#              preco_dolar    prd_dd
#  data
#  2015-03-01     -0.04558 -0.004978,
#              preco_dolar    prd_dd
#  data
#  2015-04-01     0.056276  0.004647,
#              preco_dolar    prd_dd
#  data
#  2015-05-01     -0.04952  0.000331,
#              preco_dolar    prd_dd
#  data
#  2015-06-01     0.003307  0.000993,
#              preco_dolar    prd_dd
#  data
#  2015-07-01     0.035192 -0.000662,
#              preco_dolar    prd_dd
#  data
#  2015-08-01    -0.026633  0.000331,
#              preco_dolar  prd_dd
#  data
#  2015-09-01    -0.055247     0.0,
#              preco_dolar    prd_dd
#  data
#  2015-10-01     0.014523 -0.000662,
#              preco_dolar    prd_dd
#  data
#  2015-11-01     0.001696  0.000331,
#              preco_dolar  prd_dd
#  data
#  2015-12-01    -0.013935     0.0,
#              preco_dolar    prd_dd
#  data
#  2016-01-01    -0.022546  0.030631,
#              preco_dolar   prd_dd
#  data
#  2016-02-01    -0.041143 -0.00935,
#              preco_dolar    prd_dd
#  data
#  2016-03-01     0.029047 -0.019628,
#              preco_dolar    prd_dd
#  data
#  2016-04-01     0.085982 -0.014978,
#              preco_dolar    prd_dd
#  data
#  2016-05-01     0.105773 -0.016228,
#              preco_dolar    prd_dd
#  data
#  2016-06-01     0.131182 -0.003414,
#              preco_dolar    prd_dd
#  data
#  2016-07-01     -0.04275 -0.003083,
#              preco_dolar  prd_dd
#  data
#  2016-08-01    -0.046876     0.0,
#              preco_dolar    prd_dd
#  data
#  2016-09-01    -0.041633 -0.003436,
#              preco_dolar    prd_dd
#  data
#  2016-10-01     -0.01366 -0.000344,
#              preco_dolar    prd_dd
#  data
#  2016-11-01    -0.027555 -0.000344,
#              preco_dolar    prd_dd
#  data
#  2016-12-01    -0.002205 -0.003105,
#              preco_dolar    prd_dd
#  data
#  2017-01-01     0.017369  0.092668,
#              preco_dolar    prd_dd
#  data
#  2017-02-01     0.000375  0.010963,
#              preco_dolar    prd_dd
#  data
#  2017-03-01    -0.061289  0.018213,
#              preco_dolar    prd_dd
#  data
#  2017-04-01    -0.066138  0.017587,
#              preco_dolar    prd_dd
#  data
#  2017-05-01     0.024564  0.011951,
#              preco_dolar    prd_dd
#  data
#  2017-06-01    -0.026721  0.006218,
#              preco_dolar    prd_dd
#  data
#  2017-07-01     0.076409  0.002064,
#              preco_dolar    prd_dd
#  data
#  2017-08-01    -0.018477 -0.001474,
#              preco_dolar    prd_dd
#  data
#  2017-09-01     0.012944  0.001179,
#              preco_dolar    prd_dd
#  data
#  2017-10-01    -0.003705 -0.000589,
#              preco_dolar    prd_dd
#  data
#  2017-11-01     0.013169  0.000295,
#              preco_dolar    prd_dd
#  data
#  2017-12-01    -0.005991 -0.000295,
#              preco_dolar    prd_dd
#  data
#  2018-01-01    -0.006652 -0.041842,
#              preco_dolar    prd_dd
#  data
#  2018-02-01     0.029135  0.001536,
#              preco_dolar    prd_dd
#  data
#  2018-03-01     0.050186  0.010989,
#              preco_dolar    prd_dd
#  data
#  2018-04-01     0.035105  0.009066,
#              preco_dolar    prd_dd
#  data
#  2018-05-01    -0.057764  0.001503,
#              preco_dolar    prd_dd
#  data
#  2018-06-01    -0.054532  0.004795,
#              preco_dolar    prd_dd
#  data
#  2018-07-01     0.028506  0.001195,
#              preco_dolar    prd_dd
#  data
#  2018-08-01    -0.008645  0.002088,
#              preco_dolar    prd_dd
#  data
#  2018-09-01     0.016249  0.003272,
#              preco_dolar    prd_dd
#  data
#  2018-10-01     0.034416  0.003854,
#              preco_dolar    prd_dd
#  data
#  2018-11-01    -0.079505 -0.000592,
#              preco_dolar  prd_dd
#  data
#  2018-12-01    -0.062385     0.0,
#              preco_dolar    prd_dd
#  data
#  2019-01-01    -0.014915 -0.046661,
#              preco_dolar    prd_dd
#  data
#  2019-02-01     0.015128 -0.009036,
#              preco_dolar   prd_dd
#  data
#  2019-03-01    -0.025233 -0.00975,
#              preco_dolar    prd_dd
#  data
#  2019-04-01    -0.035451  0.000316,
#              preco_dolar    prd_dd
#  data
#  2019-05-01    -0.002662 -0.001898,
#              preco_dolar   prd_dd
#  data
#  2019-06-01     0.078623 -0.00095,
#              preco_dolar    prd_dd
#  data
#  2019-07-01    -0.016922  0.005687,
#              preco_dolar    prd_dd
#  data
#  2019-08-01     0.013606 -0.000315,
#              preco_dolar    prd_dd
#  data
#  2019-09-01    -0.007821 -0.003789,
#              preco_dolar    prd_dd
#  data
#  2019-10-01     0.029866  0.000316,
#              preco_dolar    prd_dd
#  data
#  2019-11-01     0.000249  0.000316,
#              preco_dolar    prd_dd
#  data
#  2019-12-01    -0.008023  0.002211,
#              preco_dolar    prd_dd
#  data
#  2020-01-01    -0.017761  0.059102,
#              preco_dolar    prd_dd
#  data
#  2020-02-01    -0.043959  0.013879,
#              preco_dolar    prd_dd
#  data
#  2020-03-01    -0.037784 -0.035217,
#              preco_dolar    prd_dd
#  data
#  2020-04-01    -0.011219  0.001518,
#              preco_dolar    prd_dd
#  data
#  2020-05-01     0.019933 -0.018057,
#              preco_dolar    prd_dd
#  data
#  2020-06-01     0.075011  0.005236,
#              preco_dolar    prd_dd
#  data
#  2020-07-01     0.040804 -0.000307,
#              preco_dolar    prd_dd
#  data
#  2020-08-01     0.068456  0.003375,
#              preco_dolar    prd_dd
#  data
#  2020-09-01     0.104173  0.003058,
#              preco_dolar    prd_dd
#  data
#  2020-10-01     0.081739  0.001221,
#              preco_dolar    prd_dd
#  data
#  2020-11-01      0.07078  0.000305,
#              preco_dolar  prd_dd
#  data
#  2020-12-01    -0.025185     0.0]

# %%
# ret 
# para lag_order = 1,
# começa em fev/07 e termina em 12/2020, predições começarão em mar/07 e termina em 01/21 (essa deve ser descartada)
# enfim, necessário realinhamento dos dados após predições

# %%
print("Total de inputs: ", len(ret1))

# ret = ret[lag_order:]
# print(len(ret))

tr_for = []
for e in ret1:
    tr_for.append(results.forecast(e.values, 1)[0][0])
    
print("Tamanho das predicoes: ", len(tr_for))

print("Porém, dados não alinhados.")
# Out:
# Total de inputs:  167
# Tamanho das predicoes:  167
# Porém, dados não alinhados.

# %% [markdown]
# {df_join} possui uma observação a mais que {data}, por causa da função diff()

# %%
# Último valor absoluto antes da primeira previsão (relativa, em diff)
df_join.preco_dolar[lag_order:lag_order+1]
# Out:
# data
# 2007-02-01    16.549444
# Freq: MS, Name: preco_dolar, dtype: float64

# %%
# Reverter as transformações das previsões
# O sistema sempre prevê um passo à frente
previsao_revertida = revert(df_join.preco_dolar[lag_order:lag_order+1], np.array(tr_for))

print(previsao_revertida.shape[0])
# Out:
# 167

# %%
df_join.preco_dolar[lag_order+1:] # até dezembro/2020
# Out:
# data
# 2007-03-01    16.287273
# 2007-04-01    15.724000
# 2007-05-01    16.228636
# 2007-06-01    17.045000
# 2007-07-01    17.873636
#                 ...
# 2020-08-01    23.546667
# 2020-09-01    26.131905
# 2020-10-01    28.357619
# 2020-11-01    30.437500
# 2020-12-01    29.680500
# Freq: MS, Name: preco_dolar, Length: 166, dtype: float64

# %%
jan_2021 = previsao_revertida[-1:]
prev_insample = previsao_revertida[:-1]
prev_insample.index = df_join.preco_dolar[lag_order+1:].index
jan_2021
# Out:
# 166    23.821531
# dtype: float64

# %%
prev_insample
# Out:
# data
# 2007-03-01    16.806013
# 2007-04-01    16.710709
# 2007-05-01    16.473898
# 2007-06-01    16.495089
# 2007-07-01    16.805797
#                 ...
# 2020-08-01    21.552219
# 2020-09-01    22.031434
# 2020-10-01    22.784099
# 2020-11-01    23.411405
# 2020-12-01    23.980695
# Freq: MS, Length: 166, dtype: float64

# %%
y = df_join.preco_dolar[lag_order+1:]
y_hat = prev_insample

plt.plot(y)
plt.plot(y_hat)

# %%
# Plot novamente, com dados normalizados
from sklearn.preprocessing import StandardScaler as sc

s1 = sc()
s2 = sc()
y_norm = s1.fit_transform(y.values.reshape(-1,1))
yhat_norm = s2.fit_transform(y_hat.values.reshape(-1,1))

plt.figure(figsize=(20,10))
plt.plot(y_norm, color='tab:cyan')
plt.plot(yhat_norm, color='tab:orange')

# %%
for e in range(int(df_join.shape[0]/12)):
    def slice(var):
        return var[12*e:(12)*(e+1)-1]
    
    fig, ax1 = plt.subplots(figsize=(15,8))
    ax1.plot(slice(y))
    ax2 = ax1.twinx()
    ax2.plot(slice(y_hat), color="tab:orange")
    plt.title(f'Previsões em laranja vs. Reais em Azul, período inicial: {slice(y).index[0]}')
    plt.show()

# %%
# Modelo não foi capaz de superar o baseline de lag+1

print("Erro do modelo: ", mean_absolute_error(y, y_hat)) # MAE
print("Erro do baseline: ", mean_absolute_error(y, y.shift().fillna(method='bfill')), " x(t+1)=x(t)") # MAE
# Out:
# Erro do modelo:  4.675930029520678
# Erro do baseline:  1.1069500397003418  x(t+1)=x(t)
