# %%
import io
import requests
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt

# %%
codigos = {
    "algodao":39429,
    "milho_1a":39441,
    "milho_2a":39442,
    "soja":39443,
    "trigo":39445,
    "cafe_total":40527,
    "cafe_arabica":39454,
    "cafe_conilon":39455,
    "cana_acucar":39456,
}

# %%
codigo = codigos['soja']

# %%
# Aqui tem HELP da tabela e descrição dos campos!!!
# http://api.sidra.ibge.gov.br/
# http://api.sidra.ibge.gov.br/home/ajuda
# http://api.sidra.ibge.gov.br/desctabapi.aspx?c=6588

'''
1618 (ultimo mês), 1612 (até último ano), 6588 (completo)
https://www.ibge.gov.br/estatisticas/economicas/agricultura-e-pecuaria/9201-levantamento-sistematico-da-producao-agricola.html?=&t=resultados
https://www.ibge.gov.br/estatisticas/sociais/populacao/9201-levantamento-sistematico-da-producao-agricola.html?edicao=20757&t=series-historicas
https://dados.gov.br/dataset/la-levantamento-sistematico-da-producao-agricola-lspa
https://www.ibge.gov.br/estatisticas/economicas/agricultura-epecuaria/9201-levantamento-sistematico-da-producao-agricola.html?edicao=22942&t=downloads
'''
# url = 'http://api.sidra.ibge.gov.br/values/t/1618/n1/all/v/all/p/all/c49/all/c48/all?formato=json'

# %%
url = f'http://api.sidra.ibge.gov.br/values/t/6588/n1/all/v/all/p/all/c48/{codigo}?formato=json'

df=pd.read_json(url)
cod_table = df.iloc[0]
df = df[1:]
df.V = pd.to_numeric(df.V)

# %%
cod_table
# Out:
# NC        Nível Territorial (Código)
# NN                 Nível Territorial
# D1C                  Brasil (Código)
# D1N                           Brasil
# D2C                Variável (Código)
# D2N                         Variável
# D3C                     Mês (Código)
# D3N                              Mês
# D4C    Produto das lavouras (Código)
# D4N             Produto das lavouras
# MC        Unidade de Medida (Código)
# MN                 Unidade de Medida
# V                              Valor
# Name: 0, dtype: object

# %%
for stats in df.D2N.unique():
    print(stats)
    df[df.D2N == stats].V.plot()
    plt.show()
# Out:
# Área plantada
# Área colhida
# Produção
# Rendimento médio

# %%
df
# Out:
#     NC      NN D1C     D1N  D2C               D2N     D3C            D3N  \
# 1    1  Brasil   1  Brasil  109     Área plantada  200609  setembro 2006
# 2    1  Brasil   1  Brasil  109     Área plantada  200610   outubro 2006
# 3    1  Brasil   1  Brasil  109     Área plantada  200611  novembro 2006
# 4    1  Brasil   1  Brasil  109     Área plantada  200612  dezembro 2006
# 5    1  Brasil   1  Brasil  109     Área plantada  200701   janeiro 2007
# ..  ..     ...  ..     ...  ...               ...     ...            ...
# 680  1  Brasil   1  Brasil   36  Rendimento médio  202007     julho 2020
# 681  1  Brasil   1  Brasil   36  Rendimento médio  202008    agosto 2020
# 682  1  Brasil   1  Brasil   36  Rendimento médio  202009  setembro 2020
# 683  1  Brasil   1  Brasil   36  Rendimento médio  202010   outubro 2020
# 684  1  Brasil   1  Brasil   36  Rendimento médio  202011  novembro 2020
#
#        D4C        D4N    MC                       MN         V
# 1    39443  1.15 Soja  1006                 Hectares  22046825
# 2    39443  1.15 Soja  1006                 Hectares  22046825
# 3    39443  1.15 Soja  1006                 Hectares  21991638
# 4    39443  1.15 Soja  1006                 Hectares  21994243
# 5    39443  1.15 Soja  1006                 Hectares  20686139
# ..     ...        ...   ...                      ...       ...
# 680  39443  1.15 Soja    33  Quilogramas por Hectare      3254
# 681  39443  1.15 Soja    33  Quilogramas por Hectare      3265
# 682  39443  1.15 Soja    33  Quilogramas por Hectare      3275
# 683  39443  1.15 Soja    33  Quilogramas por Hectare      3279
# 684  39443  1.15 Soja    33  Quilogramas por Hectare      3280
#
# [684 rows x 13 columns]
