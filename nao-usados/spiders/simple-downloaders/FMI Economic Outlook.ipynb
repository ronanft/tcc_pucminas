# %%
# !pip install datapackage
# !pip install pandas

# %%
import datapackage
import pandas as pd

data_url = 'https://datahub.io/core/imf-weo/datapackage.json'

# to load Data Package into storage
package = datapackage.Package(data_url)

# to load only tabular data
resources = package.resources
# Out:
# [<datapackage.resource.Resource at 0x12e59d2fec8>,
#  <datapackage.resource.Resource at 0x12e59d3f3c8>,
#  <datapackage.resource.Resource at 0x12e59d3bf08>,
#  <datapackage.resource.Resource at 0x12e56da09c8>,
#  <datapackage.resource.Resource at 0x12e56db0048>,
#  <datapackage.resource.Resource at 0x12e56dc76c8>,
#  <datapackage.resource.Resource at 0x12e56dcfe08>,
#  <datapackage.resource.Resource at 0x12e56dc2fc8>,
#  <datapackage.resource.Resource at 0x12e56dddf48>]

# %%
dir(resources[0])
# Out:
# ['_Resource__base_path',
#  '_Resource__build',
#  '_Resource__current_descriptor',
#  '_Resource__errors',
#  '_Resource__get_integrity',
#  '_Resource__get_relations',
#  '_Resource__get_table',
#  '_Resource__next_descriptor',
#  '_Resource__package',
#  '_Resource__profile',
#  '_Resource__relations',
#  '_Resource__source_inspection',
#  '_Resource__storage',
#  '_Resource__strict',
#  '_Resource__table',
#  '_Resource__table_options',
#  '_Resource__unsafe',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'check_integrity',
#  'check_relations',
#  'commit',
#  'data',
#  'descriptor',
#  'drop_relations',
#  'errors',
#  'get_foreign_keys_values',
#  'group',
#  'headers',
#  'infer',
#  'inline',
#  'iter',
#  'local',
#  'multipart',
#  'name',
#  'package',
#  'profile',
#  'raw_iter',
#  'raw_read',
#  'read',
#  'remote',
#  'save',
#  'schema',
#  'source',
#  'table',
#  'tabular',
#  'valid']

# %%
resources[0].name
# Out:
# 'validation_report'

# %%
for resource in resources:
    try:
        print(resource.name)
    except:
        pass
# Out:
# validation_report
# indicators_csv
# values_csv
# indicators_json
# values_json
# imf-weo_zip
# values_csv_preview
# indicators
# values

# %%
d = pd.read_json(resources[-1].data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-1f206b80052d> in <module>
# ----> 1 d = pd.read_json(resources[-1].data)
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     197                 else:
#     198                     kwargs[new_arg_name] = new_arg_value
# --> 199             return func(*args, **kwargs)
#     200
#     201         return cast(F, wrapper)
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     294                 )
#     295                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 296             return func(*args, **kwargs)
#     297
#     298         return wrapper
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\json\_json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression, nrows)
#     592     compression = infer_compression(path_or_buf, compression)
#     593     filepath_or_buffer, _, compression, should_close = get_filepath_or_buffer(
# --> 594         path_or_buf, encoding=encoding, compression=compression
#     595     )
#     596
#
# ~\AppData\Roaming\Python\Python37\site-packages\pandas\io\common.py in get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     241     if not is_file_like(filepath_or_buffer):
#     242         msg = f"Invalid file path or buffer object type: {type(filepath_or_buffer)}"
# --> 243         raise ValueError(msg)
#     244
#     245     return filepath_or_buffer, None, compression, False
#
# ValueError: Invalid file path or buffer object type: <class 'list'>

# %%
for resource in resources:
    if resource.tabular:
        data = pd.read_csv(resource.descriptor['path'])
        print(resource.name)
        print (data)
        print('\n\n\n\n\n\n\n')
# Out:
# indicators_csv
#               id                                              title  \
# 0            BCA             Current account balance (U.S. dollars)
# 1      BCA_NGDPD           Current account balance (Percent of GDP)
# 2        FLIBOR6  Six-month London interbank offered rate (LIBOR...
# 3            GGR     General government revenue (National currency)
# 4       GGR_NGDP        General government revenue (Percent of GDP)
# 5           GGSB  General government structural balance (Nationa...
# 6     GGSB_NPGDP  General government structural balance (Percent...
# 7            GGX  General government total expenditure (National...
# 8         GGXCNL  General government net lending/borrowing (Nati...
# 9    GGXCNL_NGDP  General government net lending/borrowing (Perc...
# 10       GGXONLB  General government primary net lending/borrowi...
# 11  GGXONLB_NGDP  General government primary net lending/borrowi...
# 12        GGXWDG  General government gross debt (National currency)
# 13   GGXWDG_NGDP     General government gross debt (Percent of GDP)
# 14        GGXWDN    General government net debt (National currency)
# 15   GGXWDN_NGDP       General government net debt (Percent of GDP)
# 16      GGX_NGDP  General government total expenditure (Percent ...
# 17            LE                               Employment (Persons)
# 18            LP                               Population (Persons)
# 19           LUR   Unemployment rate (Percent of total labor force)
# 20    NGAP_NPGDP  Output gap in percent of potential GDP (Percen...
# 21          NGDP  Gross domestic product, current prices (Nation...
# 22         NGDPD  Gross domestic product, current prices (U.S. d...
# 23       NGDPDPC  Gross domestic product per capita, current pri...
# 24        NGDPPC  Gross domestic product per capita, current pri...
# 25       NGDPRPC  Gross domestic product per capita, constant pr...
# 26        NGDP_D           Gross domestic product, deflator (Index)
# 27       NGDP_FY  Gross domestic product corresponding to fiscal...
# 28        NGDP_R  Gross domestic product, constant prices (Natio...
# 29     NGDP_RPCH  Gross domestic product, constant prices (Perce...
# 30     NGSD_NGDP            Gross national savings (Percent of GDP)
# 31      NID_NGDP                  Total investment (Percent of GDP)
# 32          PCPI         Inflation, average consumer prices (Index)
# 33         PCPIE   Inflation, end of period consumer prices (Index)
# 34      PCPIEPCH  Inflation, end of period consumer prices (Perc...
# 35       PCPIPCH  Inflation, average consumer prices (Percent ch...
# 36         PPPEX  Implied PPP conversion rate (National currency...
# 37        PPPGDP  Gross domestic product based on purchasing-pow...
# 38         PPPPC  Gross domestic product based on purchasing-pow...
# 39         PPPSH  Gross domestic product based on purchasing-pow...
# 40      TMG_RPCH        Volume of Imports of goods (Percent change)
# 41       TM_RPCH  Volume of imports of goods and services (Perce...
# 42      TXG_RPCH        Volume of exports of goods (Percent change)
# 43       TX_RPCH  Volume of exports of goods and services (Perce...
#
#                                           description  \
# 0   Current account is all transactions other than...
# 1   Current account is all transactions other than...
# 2                                                 NaN
# 3   Revenue consists of taxes, social contribution...
# 4   Revenue consists of taxes, social contribution...
# 5   The structural budget balance refers to the ge...
# 6   The structural budget balance refers to the ge...
# 7   Total expenditure consists of total expense an...
# 8   Net lending (+)/ borrowing (?) is calculated a...
# 9   Net lending (+)/ borrowing (?) is calculated a...
# 10  Primary net lending/borrowing is net lending (...
# 11  Primary net lending/borrowing is net lending (...
# 12  Gross debt consists of all liabilities that re...
# 13  Gross debt consists of all liabilities that re...
# 14  Net debt is calculated as gross debt minus fin...
# 15  Net debt is calculated as gross debt minus fin...
# 16  Total expenditure consists of total expense an...
# 17  Employment can be defined by either the nation...
# 18  For census purposes, the total population of t...
# 19  Unemployment rate can be defined by either the...
# 20  Output gaps for advanced economies are calcula...
# 21  Expressed in billions of national currency uni...
# 22  Values are based upon GDP in national currency...
# 23  GDP is expressed in current U.S. dollars per p...
# 24  GDP is expressed in current national currency ...
# 25  GDP is expressed in constant national currency...
# 26  The GDP deflator is derived by dividing curren...
# 27  Gross domestic product corresponding to fiscal...
# 28  Expressed in billions of national currency uni...
# 29  Annual percentages of constant price GDP are y...
# 30  Expressed as a ratio of gross national savings...
# 31  Expressed as a ratio of total investment in cu...
# 32  Expressed in averages for the year, not end-of...
# 33  Expressed in end of the period, not annual ave...
# 34  Annual percentages of end of period consumer p...
# 35  Annual percentages of average consumer prices ...
# 36  Expressed in national currency per current int...
# 37  These data form the basis for the country weig...
# 38  Expressed in GDP in PPP dollars per person. Da...
# 39  Expressed in percent of world GDP in PPP dolla...
# 40  Percent change of volume of imports of goods r...
# 41  Percent change of volume of imports refers to ...
# 42  Percent change of volume of exports of goods r...
# 43  Percent change of volume of exports refers to ...
#
#                                                 units     scale
# 0                                        U.S. dollars  Billions
# 1                                      Percent of GDP       NaN
# 2                                             Percent       NaN
# 3                                   National currency  Billions
# 4                                      Percent of GDP       NaN
# 5                                   National currency  Billions
# 6                            Percent of potential GDP       NaN
# 7                                   National currency  Billions
# 8                                   National currency  Billions
# 9                                      Percent of GDP       NaN
# 10                                  National currency  Billions
# 11                                     Percent of GDP       NaN
# 12                                  National currency  Billions
# 13                                     Percent of GDP       NaN
# 14                                  National currency  Billions
# 15                                     Percent of GDP       NaN
# 16                                     Percent of GDP       NaN
# 17                                            Persons  Millions
# 18                                            Persons  Millions
# 19                       Percent of total labor force       NaN
# 20                           Percent of potential GDP       NaN
# 21                                  National currency  Billions
# 22                                       U.S. dollars  Billions
# 23                                       U.S. dollars     Units
# 24                                  National currency     Units
# 25                                  National currency     Units
# 26                                              Index       NaN
# 27                                  National currency  Billions
# 28                                  National currency  Billions
# 29                                     Percent change       NaN
# 30                                     Percent of GDP       NaN
# 31                                     Percent of GDP       NaN
# 32                                              Index       NaN
# 33                                              Index       NaN
# 34                                     Percent change       NaN
# 35                                     Percent change       NaN
# 36  National currency per current international do...       NaN
# 37                       Current international dollar  Billions
# 38                       Current international dollar     Units
# 39                                            Percent       NaN
# 40                                     Percent change       NaN
# 41                                     Percent change       NaN
# 42                                     Percent change       NaN
# 43                                     Percent change       NaN
# values_csv
#        Country  Indicator  Year    Value
# 0          AFG     NGDP_R  2002   183.26
# 1          AFG     NGDP_R  2003  198.736
# 2          AFG     NGDP_R  2004  200.069
# 3          AFG     NGDP_R  2005  223.737
# 4          AFG     NGDP_R  2006  235.731
# ...        ...        ...   ...      ...
# 289638     ZWE  BCA_NGDPD  2016  -23.763
# 289639     ZWE  BCA_NGDPD  2017  -22.904
# 289640     ZWE  BCA_NGDPD  2018  -23.007
# 289641     ZWE  BCA_NGDPD  2019  -22.717
# 289642     ZWE  BCA_NGDPD  2020  -23.486
#
# [289643 rows x 4 columns]
#
#
#
#
#
#
#
#
# indicators
#               id                                              title  \
# 0            BCA             Current account balance (U.S. dollars)
# 1      BCA_NGDPD           Current account balance (Percent of GDP)
# 2        FLIBOR6  Six-month London interbank offered rate (LIBOR...
# 3            GGR     General government revenue (National currency)
# 4       GGR_NGDP        General government revenue (Percent of GDP)
# 5           GGSB  General government structural balance (Nationa...
# 6     GGSB_NPGDP  General government structural balance (Percent...
# 7            GGX  General government total expenditure (National...
# 8         GGXCNL  General government net lending/borrowing (Nati...
# 9    GGXCNL_NGDP  General government net lending/borrowing (Perc...
# 10       GGXONLB  General government primary net lending/borrowi...
# 11  GGXONLB_NGDP  General government primary net lending/borrowi...
# 12        GGXWDG  General government gross debt (National currency)
# 13   GGXWDG_NGDP     General government gross debt (Percent of GDP)
# 14        GGXWDN    General government net debt (National currency)
# 15   GGXWDN_NGDP       General government net debt (Percent of GDP)
# 16      GGX_NGDP  General government total expenditure (Percent ...
# 17            LE                               Employment (Persons)
# 18            LP                               Population (Persons)
# 19           LUR   Unemployment rate (Percent of total labor force)
# 20    NGAP_NPGDP  Output gap in percent of potential GDP (Percen...
# 21          NGDP  Gross domestic product, current prices (Nation...
# 22         NGDPD  Gross domestic product, current prices (U.S. d...
# 23       NGDPDPC  Gross domestic product per capita, current pri...
# 24        NGDPPC  Gross domestic product per capita, current pri...
# 25       NGDPRPC  Gross domestic product per capita, constant pr...
# 26        NGDP_D           Gross domestic product, deflator (Index)
# 27       NGDP_FY  Gross domestic product corresponding to fiscal...
# 28        NGDP_R  Gross domestic product, constant prices (Natio...
# 29     NGDP_RPCH  Gross domestic product, constant prices (Perce...
# 30     NGSD_NGDP            Gross national savings (Percent of GDP)
# 31      NID_NGDP                  Total investment (Percent of GDP)
# 32          PCPI         Inflation, average consumer prices (Index)
# 33         PCPIE   Inflation, end of period consumer prices (Index)
# 34      PCPIEPCH  Inflation, end of period consumer prices (Perc...
# 35       PCPIPCH  Inflation, average consumer prices (Percent ch...
# 36         PPPEX  Implied PPP conversion rate (National currency...
# 37        PPPGDP  Gross domestic product based on purchasing-pow...
# 38         PPPPC  Gross domestic product based on purchasing-pow...
# 39         PPPSH  Gross domestic product based on purchasing-pow...
# 40      TMG_RPCH        Volume of Imports of goods (Percent change)
# 41       TM_RPCH  Volume of imports of goods and services (Perce...
# 42      TXG_RPCH        Volume of exports of goods (Percent change)
# 43       TX_RPCH  Volume of exports of goods and services (Perce...
#
#                                           description  \
# 0   Current account is all transactions other than...
# 1   Current account is all transactions other than...
# 2                                                 NaN
# 3   Revenue consists of taxes, social contribution...
# 4   Revenue consists of taxes, social contribution...
# 5   The structural budget balance refers to the ge...
# 6   The structural budget balance refers to the ge...
# 7   Total expenditure consists of total expense an...
# 8   Net lending (+)/ borrowing (?) is calculated a...
# 9   Net lending (+)/ borrowing (?) is calculated a...
# 10  Primary net lending/borrowing is net lending (...
# 11  Primary net lending/borrowing is net lending (...
# 12  Gross debt consists of all liabilities that re...
# 13  Gross debt consists of all liabilities that re...
# 14  Net debt is calculated as gross debt minus fin...
# 15  Net debt is calculated as gross debt minus fin...
# 16  Total expenditure consists of total expense an...
# 17  Employment can be defined by either the nation...
# 18  For census purposes, the total population of t...
# 19  Unemployment rate can be defined by either the...
# 20  Output gaps for advanced economies are calcula...
# 21  Expressed in billions of national currency uni...
# 22  Values are based upon GDP in national currency...
# 23  GDP is expressed in current U.S. dollars per p...
# 24  GDP is expressed in current national currency ...
# 25  GDP is expressed in constant national currency...
# 26  The GDP deflator is derived by dividing curren...
# 27  Gross domestic product corresponding to fiscal...
# 28  Expressed in billions of national currency uni...
# 29  Annual percentages of constant price GDP are y...
# 30  Expressed as a ratio of gross national savings...
# 31  Expressed as a ratio of total investment in cu...
# 32  Expressed in averages for the year, not end-of...
# 33  Expressed in end of the period, not annual ave...
# 34   Annual percentages of end of period consumer ...
# 35  Annual percentages of average consumer prices ...
# 36  Expressed in national currency per current int...
# 37  These data form the basis for the country weig...
# 38  Expressed in GDP in PPP dollars per person. Da...
# 39  Expressed in percent of world GDP in PPP dolla...
# 40  Percent change of volume of imports of goods r...
# 41  Percent change of volume of imports refers to ...
# 42  Percent change of volume of exports of goods r...
# 43  Percent change of volume of exports refers to ...
#
#                                                 units     scale
# 0                                        U.S. dollars  Billions
# 1                                      Percent of GDP       NaN
# 2                                             Percent       NaN
# 3                                   National currency  Billions
# 4                                      Percent of GDP       NaN
# 5                                   National currency  Billions
# 6                            Percent of potential GDP       NaN
# 7                                   National currency  Billions
# 8                                   National currency  Billions
# 9                                      Percent of GDP       NaN
# 10                                  National currency  Billions
# 11                                     Percent of GDP       NaN
# 12                                  National currency  Billions
# 13                                     Percent of GDP       NaN
# 14                                  National currency  Billions
# 15                                     Percent of GDP       NaN
# 16                                     Percent of GDP       NaN
# 17                                            Persons  Millions
# 18                                            Persons  Millions
# 19                       Percent of total labor force       NaN
# 20                           Percent of potential GDP       NaN
# 21                                  National currency  Billions
# 22                                       U.S. dollars  Billions
# 23                                       U.S. dollars     Units
# 24                                  National currency     Units
# 25                                  National currency     Units
# 26                                              Index       NaN
# 27                                  National currency  Billions
# 28                                  National currency  Billions
# 29                                     Percent change       NaN
# 30                                     Percent of GDP       NaN
# 31                                     Percent of GDP       NaN
# 32                                              Index       NaN
# 33                                              Index       NaN
# 34                                     Percent change       NaN
# 35                                     Percent change       NaN
# 36  National currency per current international do...       NaN
# 37                       Current international dollar  Billions
# 38                       Current international dollar     Units
# 39                                            Percent       NaN
# 40                                     Percent change       NaN
# 41                                     Percent change       NaN
# 42                                     Percent change       NaN
# 43                                     Percent change       NaN
# values
#        Country  Indicator  Year    Value
# 0          AFG     NGDP_R  2002   183.26
# 1          AFG     NGDP_R  2003  198.736
# 2          AFG     NGDP_R  2004  200.069
# 3          AFG     NGDP_R  2005  223.737
# 4          AFG     NGDP_R  2006  235.731
# ...        ...        ...   ...      ...
# 289638     ZWE  BCA_NGDPD  2016  -23.763
# 289639     ZWE  BCA_NGDPD  2017  -22.904
# 289640     ZWE  BCA_NGDPD  2018  -23.007
# 289641     ZWE  BCA_NGDPD  2019  -22.717
# 289642     ZWE  BCA_NGDPD  2020  -23.486
#
# [289643 rows x 4 columns]
