# %%
# !pip install scrapy
# !pip install pyexcel pyexcel-xls pyexcel-xlsx

# %%
import scrapy
from urllib.parse import urlencode
import ast
import pyexcel as p

# %%
class CepeaSpider(scrapy.Spider):
    
    name = "cepea"
    temp_folder = '../temp/'
    folder = '../files/'
    path = f'{name}.xls'

    params = {
        'tabela_id': 23, 
        'data_inicial':'01/12/2020',
        'periodicidade':1,
        'data_final':'15/12/2020',
    }
    
    start_urls = [
        'https://www.cepea.esalq.usp.br/br/consultas-ao-banco-de-dados-do-site.aspx?' + urlencode(params),
    ]
    
    def parse(self, response):
        final_url = ast.literal_eval(response.text)
        arquivo = final_url['arquivo'].replace("\\", "")
        # print(arquivo)
        yield scrapy.Request(
            url=arquivo,
            callback=self.save_pdf
        )
    
    def save_pdf(self, response):
        self.logger.info('Saving PDF %s', self.temp_folder + self.path)
        with open(self.temp_folder + self.path, 'wb') as f:
            f.write(response.body)

# %%
# %%capture
from scrapy.crawler import CrawlerProcess

process = CrawlerProcess({
    'USER_AGENT': 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1)'
})
process.crawl(CepeaSpider)
process.start()
# Out:
# 2020-12-17 16:08:09 [scrapy.utils.log] INFO: Scrapy 2.4.1 started (bot: scrapybot)
# 2020-12-17 16:08:09 [scrapy.utils.log] INFO: Versions: lxml 4.4.1.0, libxml2 2.9.9, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 20.3.0, Python 3.7.4 (default, Aug  9 2019, 18:34:13) [MSC v.1915 64 bit (AMD64)], pyOpenSSL 19.0.0 (OpenSSL 1.1.1d  10 Sep 2019), cryptography 2.7, Platform Windows-10-10.0.19041-SP0
# 2020-12-17 16:08:09 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2020-12-17 16:08:09 [scrapy.crawler] INFO: Overridden settings:
# {'USER_AGENT': 'Mozilla/4.0 (compatible; MSIE 7.0; Windows NT 5.1)'}
# 2020-12-17 16:08:09 [scrapy.extensions.telnet] INFO: Telnet Password: b240b6756af39247
# 2020-12-17 16:08:09 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# 2020-12-17 16:08:09 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2020-12-17 16:08:09 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2020-12-17 16:08:09 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2020-12-17 16:08:09 [scrapy.core.engine] INFO: Spider opened
# 2020-12-17 16:08:09 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2020-12-17 16:08:09 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2020-12-17 16:08:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.cepea.esalq.usp.br/br/consultas-ao-banco-de-dados-do-site.aspx?tabela_id=23&data_inicial=01%2F12%2F2020&periodicidade=1&data_final=15%2F12%2F2020> (referer: None)
# 2020-12-17 16:08:10 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.cepea.esalq.usp.br/br/indicador/consulta/cepea-consulta-20201217160811.xls> (referer: https://www.cepea.esalq.usp.br/br/consultas-ao-banco-de-dados-do-site.aspx?tabela_id=23&data_inicial=01%2F12%2F2020&periodicidade=1&data_final=15%2F12%2F2020)
# 2020-12-17 16:08:11 [cepea] INFO: Saving PDF ../temp/cepea.xls
# 2020-12-17 16:08:11 [scrapy.core.engine] INFO: Closing spider (finished)
# 2020-12-17 16:08:11 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 871,
#  'downloader/request_count': 2,
#  'downloader/request_method_count/GET': 2,
#  'downloader/response_bytes': 7092,
#  'downloader/response_count': 2,
#  'downloader/response_status_count/200': 2,
#  'elapsed_time_seconds': 1.096004,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2020, 12, 17, 19, 8, 11, 60735),
#  'log_count/DEBUG': 2,
#  'log_count/INFO': 11,
#  'request_depth_max': 1,
#  'response_received_count': 2,
#  'scheduler/dequeued': 2,
#  'scheduler/dequeued/memory': 2,
#  'scheduler/enqueued': 2,
#  'scheduler/enqueued/memory': 2,
#  'start_time': datetime.datetime(2020, 12, 17, 19, 8, 9, 964731)}
# 2020-12-17 16:08:11 [scrapy.core.engine] INFO: Spider closed (finished)

# %%
# %%capture
p.save_book_as(file_name = CepeaSpider.temp_folder + CepeaSpider.path,
               dest_file_name = CepeaSpider.folder + CepeaSpider.path + 'x')
# Out:
# 2020-12-17 16:09:02 [pyexcel.internal.source_plugin.SourcePluginManager] DEBUG: load me now:book-read
# 2020-12-17 16:09:02 [pyexcel.internal.plugins.IOPluginManager] DEBUG: load <class 'pyexcel.plugins.parsers.excel.ExcelParser'> now for 'xls'
# 2020-12-17 16:09:02 [pyexcel_io.plugins.NewIOManager] DEBUG: load <class 'pyexcel_xls.xlsr.XLSInFile'> now for 'file-xls'
# 2020-12-17 16:09:02 [pyexcel.internal.source_plugin.SourcePluginManager] DEBUG: load me now:book-write
# 2020-12-17 16:09:02 [pyexcel.internal.source_plugin.SourcePluginManager] DEBUG: import pyexcel.plugins.sources.file_output.WriteBookToFile
# 2020-12-17 16:09:02 [pyexcel.internal.plugins.IOPluginManager] DEBUG: import pyexcel.plugins.renderers.excel.ExcelRenderer
# 2020-12-17 16:09:02 [pyexcel.internal.plugins.IOPluginManager] DEBUG: load <class 'pyexcel.plugins.renderers.excel.ExcelRenderer'> now for 'xlsx'
# 2020-12-17 16:09:02 [pyexcel.internal.source_plugin.SourcePluginManager] DEBUG: load me now:sheet-write
# 2020-12-17 16:09:02 [pyexcel.internal.source_plugin.SourcePluginManager] DEBUG: import pyexcel.plugins.sources.pydata.arraysource.ArraySource
# 2020-12-17 16:09:02 [pyexcel.internal.source_plugin.SourcePluginManager] DEBUG: load me now:sheet-write
# 2020-12-17 16:09:02 [pyexcel_io.plugins.NewIOManager] DEBUG: import pyexcel_xlsx.xlsxw.XLSXWriter
# 2020-12-17 16:09:03 [pyexcel_io.plugins.NewIOManager] DEBUG: load <class 'pyexcel_xlsx.xlsxw.XLSXWriter'> now for 'file-xlsx'
