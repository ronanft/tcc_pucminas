# %%
# !pip install scrapy
# !pip install OleFileIO_PL
# !pip install urllib

# %%
import scrapy
from urllib.parse import urlencode
import ast
from datetime import datetime
import OleFileIO_PL
import pandas as pd

# %%
import os
import pickle
from datetime import datetime

class FileAdmin():
    
    files_dir = '../files/'
    
    @classmethod
    def apaga(cls, spider, tipo):
        for file in os.listdir(cls.files_dir):
            x = file.split('.')
            if x[0] == spider and x[1] == tipo:
                os.remove(cls.files_dir + file)

    def _geranome(spider, name):
        # Gera e retorna o nome do arquivo
        marca_data = datetime.today().strftime('%Y-%m-%d')
        return f'{spider}.{name}.{marca_data}.p'
    
    @classmethod
    def grava(cls, dados, spider, name):
        filename = cls._geranome(spider, name)
        with open(cls.files_dir + filename, 'wb') as handle:
            pickle.dump(dados, handle)

# %%
class CepeaSpider(scrapy.Spider):
    
    name = "cepea"
    
    def debug(self):
        print(self.name)
        
    def __new__(cls, codinome, cod):
        instance = object.__new__(cls)
        instance.codinome = codinome
        instance.start_urls = [
            f'https://www.cepea.esalq.usp.br/br/indicador/series/{codinome}.aspx?id={cod}'
        ]
        return instance
    
    def parse(self, response):
        # Prepara resposta
        ole = OleFileIO_PL.OleFileIO(response.body)
        df = pd.read_excel(ole.openstream('Workbook'), skiprows=3)
        df = df.set_index("Data")
        
        # Apaga arquivo anterior
        FileAdmin.apaga(self.name, self.codinome)
        
        # Escreve novo arquivo
        FileAdmin.grava(
            df, 
            self.name,    # spider name
            self.codinome # codigo nome
        )

# %%
import yaml
from scrapy.crawler import CrawlerProcess
import time

# Load Settings
name = CepeaSpider.name
with open(f"{name}.yaml", 'r') as stream:
    config = yaml.safe_load(stream)

# Run spider
for k, v in config.items():
    time.sleep(10)
    process = CrawlerProcess({
        'USER_AGENT': 'Mozilla/5.0 (compatible; MSIE 7.0; Windows NT 5.0)'
    })
    process.crawl(CepeaSpider, codinome=k, cod=v)

process.start()
# Out:
# 2020-12-19 13:23:59 [scrapy.utils.log] INFO: Scrapy 2.4.1 started (bot: scrapybot)
# 2020-12-19 13:23:59 [scrapy.utils.log] INFO: Versions: lxml 4.4.1.0, libxml2 2.9.9, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 20.3.0, Python 3.7.4 (default, Aug  9 2019, 18:34:13) [MSC v.1915 64 bit (AMD64)], pyOpenSSL 19.0.0 (OpenSSL 1.1.1d  10 Sep 2019), cryptography 2.7, Platform Windows-10-10.0.19041-SP0
# 2020-12-19 13:23:59 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2020-12-19 13:23:59 [scrapy.crawler] INFO: Overridden settings:
# {'USER_AGENT': 'Mozilla/5.0 (compatible; MSIE 7.0; Windows NT 5.0)'}
# 2020-12-19 13:23:59 [scrapy.extensions.telnet] INFO: Telnet Password: 07ed20f2dd991a74
# 2020-12-19 13:23:59 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# 2020-12-19 13:23:59 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2020-12-19 13:23:59 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2020-12-19 13:23:59 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2020-12-19 13:23:59 [scrapy.core.engine] INFO: Spider opened
# 2020-12-19 13:23:59 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2020-12-19 13:23:59 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2020-12-19 13:24:09 [scrapy.utils.log] INFO: Scrapy 2.4.1 started (bot: scrapybot)
# 2020-12-19 13:24:09 [scrapy.utils.log] INFO: Versions: lxml 4.4.1.0, libxml2 2.9.9, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 20.3.0, Python 3.7.4 (default, Aug  9 2019, 18:34:13) [MSC v.1915 64 bit (AMD64)], pyOpenSSL 19.0.0 (OpenSSL 1.1.1d  10 Sep 2019), cryptography 2
[scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2020-12-19 13:24:40 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6027
# 2020-12-19 13:24:50 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.cepea.esalq.usp.br/br/indicador/series/soja.aspx?id=92> (referer: None)
# 2020-12-19 13:24:50 [scrapy.core.engine] INFO: Closing spider (finished)
# 2020-12-19 13:24:50 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 273,
#  'downloader/request_count': 1,
#  'downloader/request_method_count/GET': 1,
#  'downloader/response_bytes': 276908,
#  'downloader/response_count': 1,
#  'downloader/response_status_count/200': 1,
#  'elapsed_time_seconds': 30.573714,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2020, 12, 19, 16, 24, 50, 531342),
#  'log_count/DEBUG': 3,
#  'log_count/INFO': 32,
#  'response_received_count': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2020, 12, 19, 16, 24, 19, 957628)}
# 2020-12-19 13:24:50 [scrapy.core.engine] INFO: Spider closed (finished)
# 2020-12-19 13:24:51 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.cepea.esalq.usp.br/br/indicador/series/milho.aspx?id=77> (referer: None)
# 2020-12-19 13:24:51 [scrapy.core.engine] INFO: Closing spider (finished)
# 2020-12-19 13:24:51 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 274,
#  'downloader/request_count': 1,
#  'downloader/request_method_count/GET': 1,
#  'downloader/response_bytes': 305068,
#  'downloader/response_count': 1,
#  'downloader/response_status_count/200': 1,
#  'elapsed_time_seconds': 21.559332,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2020, 12, 19, 16, 24, 51, 629294),
#  'log_count/DEBUG': 3,
#  'log_count/INFO': 24,
#  'response_received_count': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2020, 12, 19, 16, 24, 30, 69962)}
# 2020-12-19 13:24:51 [scrapy.core.engine] INFO: Spider closed (finished)
# 2020-12-19 13:24:52 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.cepea.esalq.usp.br/br/indicador/series/acucar.aspx?id=53> (referer: None)
# 2020-12-19 13:24:52 [scrapy.core.engine] INFO: Closing spider (finished)
# 2020-12-19 13:24:52 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 275,
#  'downloader/request_count': 1,
#  'downloader/request_method_count/GET': 1,
#  'downloader/response_bytes': 326060,
#  'downloader/response_count': 1,
#  'downloader/response_status_count/200': 1,
#  'elapsed_time_seconds': 42.625788,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2020, 12, 19, 16, 24, 52, 447868),
#  'log_count/DEBUG': 6,
#  'log_count/INFO': 49,
#  'response_received_count': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2020, 12, 19, 16, 24, 9, 822080)}
# 2020-12-19 13:24:52 [scrapy.core.engine] INFO: Spider closed (finished)
# 2020-12-19 13:24:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.cepea.esalq.usp.br/br/indicador/series/cafe.aspx?id=23> (referer: None)
# 2020-12-19 13:24:54 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.cepea.esalq.usp.br/br/indicador/series/boi-gordo.aspx?id=2> (referer: None)
# 2020-12-19 13:24:54 [scrapy.core.engine] INFO: Closing spider (finished)
# 2020-12-19 13:24:54 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 273,
#  'downloader/request_count': 1,
#  'downloader/request_method_count/GET': 1,
#  'downloader/response_bytes': 449964,
#  'downloader/response_count': 1,
#  'downloader/response_status_count/200': 1,
#  'elapsed_time_seconds': 55.062183,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2020, 12, 19, 16, 24, 54, 834987),
#  'log_count/DEBUG': 9,
#  'log_count/INFO': 63,
#  'response_received_count': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2020, 12, 19, 16, 23, 59, 772804)}
# 2020-12-19 13:24:54 [scrapy.core.engine] INFO: Spider closed (finished)
# 2020-12-19 13:24:55 [scrapy.core.engine] INFO: Closing spider (finished)
# 2020-12-19 13:24:55 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 277,
#  'downloader/request_count': 1,
#  'downloader/request_method_count/GET': 1,
#  'downloader/response_bytes': 433068,
#  'downloader/response_count': 1,
#  'downloader/response_status_count/200': 1,
#  'elapsed_time_seconds': 14.989883,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2020, 12, 19, 16, 24, 55, 120521),
#  'log_count/DEBUG': 5,
#  'log_count/INFO': 22,
#  'response_received_count': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2020, 12, 19, 16, 24, 40, 130638)}
# 2020-12-19 13:24:55 [scrapy.core.engine] INFO: Spider closed (finished)
